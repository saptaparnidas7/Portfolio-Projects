# %% [markdown]
# ## THE WEATHER DATASET

# %%
import pandas as pd

# %%
# renaming the dataset as 'data' itself , hence using data = 
#r is written to remomve the unicode error

data = pd.read_csv (r"C:\Users\Nidhin\Desktop\Megha\Data Analysis\Data Source\weatherHistory.csv")

# %%
# to view the data simply write 

data
# Out:
#                       Formatted Date        Weather Precip Type  \
# 0      2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain
# 1      2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain
# 2      2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain
# 3      2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain
# 4      2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain
# ...                              ...            ...         ...
# 96448  2016-09-09 19:00:00.000 +0200  Partly Cloudy        rain
# 96449  2016-09-09 20:00:00.000 +0200  Partly Cloudy        rain
# 96450  2016-09-09 21:00:00.000 +0200  Partly Cloudy        rain
# 96451  2016-09-09 22:00:00.000 +0200  Partly Cloudy        rain
# 96452  2016-09-09 23:00:00.000 +0200  Partly Cloudy        rain
#
#        Temperature_C  Dew_Point Temp_C  Rel Humidity_%  Wind Speed (km/h)  \
# 0           9.472222          7.388889            0.89            14.1197
# ...

# %% [markdown]
# ## How to Analyze Data Frames ?

# %% [markdown]
# •	DATA PROFILING

# %%
#We are going to explore the data first

# %% [markdown]
# ## .head

# %%
data.head ()
# Out:
#                   Formatted Date        Weather Precip Type  Temperature_C  \
# 0  2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain       9.472222
# 1  2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain       9.355556
# 2  2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain       9.377778
# 3  2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain       8.288889
# 4  2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain       8.755556
#
#    Dew_Point Temp_C  Rel Humidity_%  Wind Speed (km/h)  \
# 0          7.388889            0.89            14.1197
# 1          7.227778            0.86            14.2646
# 2          9.377778            0.89             3.9284
# 3          5.944444            0.83            14.1036
# 4          6.977778            0.83            11.0446
#
#    Wind Bearing (degrees)  Visibility_km  Loud Cover  Pressure (millibars)  \
# 0                     251        15.8263           0               1015.13
# ...

# %% [markdown]
# ## .shape

# %%
data.shape
# Out:
# (96453, 12)

# %% [markdown]
# ## .describe

# %%
data.describe ()
# Out:
#        Temperature_C  Dew_Point Temp_C  Rel Humidity_%  Wind Speed (km/h)  \
# count   96453.000000      96453.000000    96453.000000       96453.000000
# mean       11.932678         10.855029        0.734899          10.810640
# std         9.551546         10.696847        0.195473           6.913571
# min       -21.822222        -27.716667        0.000000           0.000000
# 25%         4.688889          2.311111        0.600000           5.828200
# 50%        12.000000         12.000000        0.780000           9.965900
# 75%        18.838889         18.838889        0.890000          14.135800
# max        39.905556         39.344444        1.000000          63.852600
#
#        Wind Bearing (degrees)  Visibility_km  Loud Cover  Pressure (millibars)
# count            96453.000000   96453.000000     96453.0          96453.000000
# mean               187.509232      10.347325         0.0           1003.235956
# ...

# %% [markdown]
# ## .index

# %%
data.index
# Out:
# RangeIndex(start=0, stop=96453, step=1)

# %% [markdown]
# ## .columns

# %%
data.columns
# Out:
# Index(['Formatted Date', 'Weather', 'Precip Type', 'Temperature_C',
#        'Dew_Point Temp_C', 'Rel Humidity_%', 'Wind Speed (km/h)',
#        'Wind Bearing (degrees)', 'Visibility_km', 'Loud Cover',
#        'Pressure (millibars)', 'Daily Summary'],
#       dtype='object')

# %% [markdown]
# ## .dtypes

# %%
data.dtypes
# Out:
# Formatted Date             object
# Weather                    object
# Precip Type                object
# Temperature_C             float64
# Dew_Point Temp_C          float64
# Rel Humidity_%            float64
# Wind Speed (km/h)         float64
# Wind Bearing (degrees)      int64
# Visibility_km             float64
# Loud Cover                  int64
# Pressure (millibars)      float64
# Daily Summary              object
# dtype: object

# %% [markdown]
# ## .unique

# %%
data ['Weather'] .unique ()
# Out:
# array(['Partly Cloudy', 'Mostly Cloudy', 'Overcast', 'Foggy',
#        'Breezy and Mostly Cloudy', 'Clear', 'Breezy and Partly Cloudy',
#        'Breezy and Overcast', 'Humid and Mostly Cloudy',
#        'Humid and Partly Cloudy', 'Windy and Foggy', 'Windy and Overcast',
#        'Breezy and Foggy', 'Windy and Partly Cloudy', 'Breezy',
#        'Dry and Partly Cloudy', 'Windy and Mostly Cloudy',
#        'Dangerously Windy and Partly Cloudy', 'Dry', 'Windy',
#        'Humid and Overcast', 'Light Rain', 'Drizzle', 'Windy and Dry',
#        'Dry and Mostly Cloudy', 'Breezy and Dry', 'Rain'], dtype=object)

# %% [markdown]
# ## .nunique
# nunique counts Null values as well
# Here applying on whole dataframe

# %%
data.nunique()
# Out:
# Formatted Date            96429
# Weather                      27
# Precip Type                   2
# Temperature_C              7574
# Dew_Point Temp_C           8984
# Rel Humidity_%               90
# Wind Speed (km/h)          2484
# Wind Bearing (degrees)      360
# Visibility_km               949
# Loud Cover                    1
# Pressure (millibars)       4979
# Daily Summary               214
# dtype: int64

# %%
#counts how many unique values are present in the summary column 

data ['Weather'] .nunique ()
# Out:
# 27

# %% [markdown]
# ## .count
#
# Non null values in each data frame

# %%
#here applying on whole dataframe , shows 96453 values in each column and no NULL values in any column

data.count()
# Out:
# Formatted Date            96453
# Weather                   96453
# Precip Type               95936
# Temperature_C             96453
# Dew_Point Temp_C          96453
# Rel Humidity_%            96453
# Wind Speed (km/h)         96453
# Wind Bearing (degrees)    96453
# Visibility_km             96453
# Loud Cover                96453
# Pressure (millibars)      96453
# Daily Summary             96453
# dtype: int64

# %% [markdown]
# ## .value_counts
# Shows all the unique values with their counts. This is because .nunique() function also counts Nan (NaN stands for Not A Number) values, whereas .value_counts() does not

# %%
data['Weather'].value_counts ()
# Out:
# Partly Cloudy                          31733
# Mostly Cloudy                          28094
# Overcast                               16597
# Clear                                  10890
# Foggy                                   7148
# Breezy and Overcast                      528
# Breezy and Mostly Cloudy                 516
# Breezy and Partly Cloudy                 386
# Dry and Partly Cloudy                     86
# Windy and Partly Cloudy                   67
# Light Rain                                63
# Breezy                                    54
# Windy and Overcast                        45
# Humid and Mostly Cloudy                   40
# Drizzle                                   39
# Breezy and Foggy                          35
# Windy and Mostly Cloudy                   35
# Dry                                       34
# Humid and Partly Cloudy                   17
# Dry and Mostly Cloudy                     14
# Rain                                      10
# ...

# %% [markdown]
# ## .info

# %%
data.info ()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96453 entries, 0 to 96452
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Formatted Date          96453 non-null  object
#  1   Weather                 96453 non-null  object
#  2   Precip Type             95936 non-null  object
#  3   Temperature_C           96453 non-null  float64
#  4   Dew_Point Temp_C        96453 non-null  float64
#  5   Rel Humidity_%          96453 non-null  float64
#  6   Wind Speed (km/h)       96453 non-null  float64
#  7   Wind Bearing (degrees)  96453 non-null  int64
#  8   Visibility_km           96453 non-null  float64
#  9   Loud Cover              96453 non-null  int64
#  10  Pressure (millibars)    96453 non-null  float64
#  11  Daily Summary           96453 non-null  object
# dtypes: float64(6), int64(2), object(4)
# memory usage: 8.8+ MB

# %% [markdown]
# # QUESTIONS

# %% [markdown]
# ## Q1. Find all unique 'Wind Speed' values in the data.

# %%
data.head(2)
# Out:
#                   Formatted Date        Weather Precip Type  Temperature_C  \
# 0  2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain       9.472222
# 1  2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain       9.355556
#
#    Dew_Point Temp_C  Rel Humidity_%  Wind Speed (km/h)  \
# 0          7.388889            0.89            14.1197
# 1          7.227778            0.86            14.2646
#
#    Wind Bearing (degrees)  Visibility_km  Loud Cover  Pressure (millibars)  \
# 0                     251        15.8263           0               1015.13
# 1                     259        15.8263           0               1015.63
#
#                        Daily Summary
# 0  Partly cloudy throughout the day.
# 1  Partly cloudy throughout the day.

# %%
data.nunique()
# Out:
# Formatted Date            96429
# Weather                      27
# Precip Type                   2
# Temperature_C              7574
# Dew_Point Temp_C           8984
# Rel Humidity_%               90
# Wind Speed (km/h)          2484
# Wind Bearing (degrees)      360
# Visibility_km               949
# Loud Cover                    1
# Pressure (millibars)       4979
# Daily Summary               214
# dtype: int64

# %%
data ['Wind Speed (km/h)'].nunique()
# Out:
# 2484

# %% [markdown]
# ## Q2. Find the number of times when the Weather is exactly clear.

# %%
#value_counts 

data.Weather.value_counts ()
# Out:
# Partly Cloudy                          31733
# Mostly Cloudy                          28094
# Overcast                               16597
# Clear                                  10890
# Foggy                                   7148
# Breezy and Overcast                      528
# Breezy and Mostly Cloudy                 516
# Breezy and Partly Cloudy                 386
# Dry and Partly Cloudy                     86
# Windy and Partly Cloudy                   67
# Light Rain                                63
# Breezy                                    54
# Windy and Overcast                        45
# Humid and Mostly Cloudy                   40
# Drizzle                                   39
# Breezy and Foggy                          35
# Windy and Mostly Cloudy                   35
# Dry                                       34
# Humid and Partly Cloudy                   17
# Dry and Mostly Cloudy                     14
# Rain                                      10
# ...

# %%
#if only this is entered , data is shown in boolean 

data.Weather == 'Clear'
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 96448    False
# 96449    False
# 96450    False
# 96451    False
# 96452    False
# Name: Weather, Length: 96453, dtype: bool

# %%
#filtering
#here data is entered outside to show the table like this 

data [data.Weather == 'Clear']
# Out:
#                       Formatted Date Weather Precip Type  Temperature_C  \
# 223    2006-04-18 07:00:00.000 +0200   Clear        rain       8.688889
# 309    2006-04-20 21:00:00.000 +0200   Clear        rain      12.266667
# 337    2006-04-22 01:00:00.000 +0200   Clear        rain       9.355556
# 338    2006-04-22 02:00:00.000 +0200   Clear        rain       9.861111
# 357    2006-04-22 21:00:00.000 +0200   Clear        rain      12.494444
# ...                              ...     ...         ...            ...
# 96432  2016-09-09 03:00:00.000 +0200   Clear        rain      15.594444
# 96433  2016-09-09 04:00:00.000 +0200   Clear        rain      15.011111
# 96434  2016-09-09 05:00:00.000 +0200   Clear        rain      15.016667
# 96435  2016-09-09 06:00:00.000 +0200   Clear        rain      13.872222
# 96436  2016-09-09 07:00:00.000 +0200   Clear        rain      16.072222
#
#        Dew_Point Temp_C  Rel Humidity_%  Wind Speed (km/h)  \
# ...

# %%
#.first will show us the first value of each groups created 

abc = data.groupby ('Weather')
abc.first()
# Out:
#                                                     Formatted Date  \
# Weather
# Breezy                               2006-11-05 05:00:00.000 +0100
# Breezy and Dry                       2012-03-18 11:00:00.000 +0100
# Breezy and Foggy                     2006-03-13 07:00:00.000 +0100
# Breezy and Mostly Cloudy             2006-04-12 08:00:00.000 +0200
# Breezy and Overcast                  2006-08-31 10:00:00.000 +0200
# Breezy and Partly Cloudy             2006-08-21 00:00:00.000 +0200
# Clear                                2006-04-18 07:00:00.000 +0200
# Dangerously Windy and Partly Cloudy  2007-01-29 13:00:00.000 +0100
# Drizzle                              2012-04-12 10:00:00.000 +0200
# Dry                                  2007-07-20 10:00:00.000 +0200
# Dry and Mostly Cloudy                2012-08-31 14:00:00.000 +0200
# Dry and Partly Cloudy                2007-04-23 13:00:00.000 +0200
# Foggy                                2006-04-11 18:00:00.000 +0200
# ...

# %%
#add get_group to specify which data you want to filter 
#FINAL ANSWER

data.groupby ('Weather').get_group ('Clear')
# Out:
#                       Formatted Date Weather Precip Type  Temperature_C  \
# 223    2006-04-18 07:00:00.000 +0200   Clear        rain       8.688889
# 309    2006-04-20 21:00:00.000 +0200   Clear        rain      12.266667
# 337    2006-04-22 01:00:00.000 +0200   Clear        rain       9.355556
# 338    2006-04-22 02:00:00.000 +0200   Clear        rain       9.861111
# 357    2006-04-22 21:00:00.000 +0200   Clear        rain      12.494444
# ...                              ...     ...         ...            ...
# 96432  2016-09-09 03:00:00.000 +0200   Clear        rain      15.594444
# 96433  2016-09-09 04:00:00.000 +0200   Clear        rain      15.011111
# 96434  2016-09-09 05:00:00.000 +0200   Clear        rain      15.016667
# 96435  2016-09-09 06:00:00.000 +0200   Clear        rain      13.872222
# 96436  2016-09-09 07:00:00.000 +0200   Clear        rain      16.072222
#
#        Dew_Point Temp_C  Rel Humidity_%  Wind Speed (km/h)  \
# ...

# %% [markdown]
# ## Q3. Find the number of times wind speed was exactly 14.2646 km/h

# %%
#this step to look at the data again 

data.head(2)
# Out:
#                   Formatted Date        Weather Precip Type  Temperature_C  \
# 0  2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain       9.472222
# 1  2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain       9.355556
#
#    Dew_Point Temp_C  Rel Humidity_%  Wind Speed (km/h)  \
# 0          7.388889            0.89            14.1197
# 1          7.227778            0.86            14.2646
#
#    Wind Bearing (degrees)  Visibility_km  Loud Cover  Pressure (millibars)  \
# 0                     251        15.8263           0               1015.13
# 1                     259        15.8263           0               1015.63
#
#                        Daily Summary
# 0  Partly cloudy throughout the day.
# 1  Partly cloudy throughout the day.

# %%
#without adding data outside , it will show Boolean value 

data [data [ 'Wind Speed (km/h)'] == 14.2646 ]
# Out:
#                       Formatted Date        Weather Precip Type  \
# 1      2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain
# 663    2006-04-07 15:00:00.000 +0200  Partly Cloudy        rain
# 996    2006-08-02 12:00:00.000 +0200  Mostly Cloudy        rain
# 1581   2006-12-13 21:00:00.000 +0100          Foggy        snow
# 2035   2006-12-30 19:00:00.000 +0100          Clear        snow
# ...                              ...            ...         ...
# 89047  2016-08-06 10:00:00.000 +0200  Mostly Cloudy        rain
# 90567  2016-02-09 18:00:00.000 +0100  Partly Cloudy        rain
# 92269  2016-06-17 16:00:00.000 +0200  Partly Cloudy        rain
# 93350  2016-03-30 18:00:00.000 +0200  Mostly Cloudy        rain
# 94187  2016-05-06 15:00:00.000 +0200  Partly Cloudy        rain
#
#        Temperature_C  Dew_Point Temp_C  Rel Humidity_%  Wind Speed (km/h)  \
# 1           9.355556          7.227778            0.86            14.2646
# ...

# %% [markdown]
# ## Q4. Where Whether is Partly Cloudy and their count

# %%
data [ data.Weather == 'Partly Cloudy'].count()
# Out:
# Formatted Date            31733
# Weather                   31733
# Precip Type               31635
# Temperature_C             31733
# Dew_Point Temp_C          31733
# Rel Humidity_%            31733
# Wind Speed (km/h)         31733
# Wind Bearing (degrees)    31733
# Visibility_km             31733
# Loud Cover                31733
# Pressure (millibars)      31733
# Daily Forecast            31733
# dtype: int64

# %% [markdown]
# ## Q5. Find out the NULL values in the data

# %%
#this will give Boolean 

data.isnull ()
# Out:
#        Formatted Date  Weather  Precip Type  Temperature_C  Dew_Point Temp_C  \
# 0               False    False        False          False             False
# 1               False    False        False          False             False
# 2               False    False        False          False             False
# 3               False    False        False          False             False
# 4               False    False        False          False             False
# ...               ...      ...          ...            ...               ...
# 96448           False    False        False          False             False
# 96449           False    False        False          False             False
# 96450           False    False        False          False             False
# 96451           False    False        False          False             False
# 96452           False    False        False          False             False
#
# ...

# %%
# so we will use this , .sum as a sum of all columns 
# this shows only 'Precip Type' has null values i.e 517

data.isnull ().sum ()
# Out:
# Formatted Date              0
# Weather                     0
# Precip Type               517
# Temperature_C               0
# Dew_Point Temp_C            0
# Rel Humidity_%              0
# Wind Speed (km/h)           0
# Wind Bearing (degrees)      0
# Visibility_km               0
# Loud Cover                  0
# Pressure (millibars)        0
# Daily Summary               0
# dtype: int64

# %%
#shows the sum data which is not null, here Precip Type count (95936) is less than others (96453), as it has null values  

data.notnull ().sum ()
# Out:
# Formatted Date            96453
# Weather                   96453
# Precip Type               95936
# Temperature_C             96453
# Dew_Point Temp_C          96453
# Rel Humidity_%            96453
# Wind Speed (km/h)         96453
# Wind Bearing (degrees)    96453
# Visibility_km             96453
# Loud Cover                96453
# Pressure (millibars)      96453
# Daily Summary             96453
# dtype: int64

# %% [markdown]
# ## Q6. Rename the column name 'Daily Summary' to 'Forecast'.

# %%
# this will only temporarily rename the table 

data.rename ( columns = { 'Daily Summary' : 'Daily Forecast' })
# Out:
#                       Formatted Date        Weather Precip Type  \
# 0      2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain
# 1      2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain
# 2      2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain
# 3      2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain
# 4      2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain
# ...                              ...            ...         ...
# 96448  2016-09-09 19:00:00.000 +0200  Partly Cloudy        rain
# 96449  2016-09-09 20:00:00.000 +0200  Partly Cloudy        rain
# 96450  2016-09-09 21:00:00.000 +0200  Partly Cloudy        rain
# 96451  2016-09-09 22:00:00.000 +0200  Partly Cloudy        rain
# 96452  2016-09-09 23:00:00.000 +0200  Partly Cloudy        rain
#
#        Temperature_C  Dew_Point Temp_C  Rel Humidity_%  Wind Speed (km/h)  \
# 0           9.472222          7.388889            0.89            14.1197
# ...

# %%
# to permanently rename the column 

data.rename ( columns = { 'Daily Summary' : 'Daily Forecast' } , inplace = True)

# %% [markdown]
# ## Q7. What is the mean value of VISIBILITY Column

# %%
data.Visibility_km.mean()
# Out:
# 10.347324929237148

# %% [markdown]
# ## Q8. What is the standard deviation value of Pressure (millibars)

# %%
data['Pressure (millibars)'].std()
# Out:
# 116.96990568258147

# %% [markdown]
# ## Q9. What is the variance of Rel Humidity

# %%
data['Rel Humidity_%'].var()
# Out:
# 0.03820959171844407

# %% [markdown]
# ## Q10. Find out all the instances when 'Foggy' was recorded.

# %%
#2 ways we can do this

# %%
# a) value_count

data.Weather.value_counts ()
# Out:
# Partly Cloudy                          31733
# Mostly Cloudy                          28094
# Overcast                               16597
# Clear                                  10890
# Foggy                                   7148
# Breezy and Overcast                      528
# Breezy and Mostly Cloudy                 516
# Breezy and Partly Cloudy                 386
# Dry and Partly Cloudy                     86
# Windy and Partly Cloudy                   67
# Light Rain                                63
# Breezy                                    54
# Windy and Overcast                        45
# Humid and Mostly Cloudy                   40
# Drizzle                                   39
# Breezy and Foggy                          35
# Windy and Mostly Cloudy                   35
# Dry                                       34
# Humid and Partly Cloudy                   17
# Dry and Mostly Cloudy                     14
# Rain                                      10
# ...

# %%
# B) FILTERING 

#this step gives only boolean value 
data.Weather == 'Foggy'


data[data.Weather == 'Foggy']
# Out:
#                       Formatted Date Weather Precip Type  Temperature_C  \
# 66     2006-04-11 18:00:00.000 +0200   Foggy        rain      10.911111
# 67     2006-04-11 19:00:00.000 +0200   Foggy        rain       8.800000
# 72     2006-04-12 00:00:00.000 +0200   Foggy        rain       8.200000
# 73     2006-04-12 01:00:00.000 +0200   Foggy        rain       8.177778
# 126    2006-04-14 06:00:00.000 +0200   Foggy        rain       5.211111
# ...                              ...     ...         ...            ...
# 95858  2016-09-14 05:00:00.000 +0200   Foggy        rain      13.144444
# 95859  2016-09-14 06:00:00.000 +0200   Foggy        rain      13.822222
# 95860  2016-09-14 07:00:00.000 +0200   Foggy        rain      13.872222
# 95907  2016-09-16 06:00:00.000 +0200   Foggy        rain      14.905556
# 96228  2016-09-28 15:00:00.000 +0200   Foggy        rain      22.800000
#
#        Dew_Point Temp_C  Rel Humidity_%  Wind Speed (km/h)  \
# ...

# %%
# to find out the count again

data[data.Weather == 'Foggy'].count()
# Out:
# Formatted Date            7148
# Weather                   7148
# Precip Type               7117
# Temperature_C             7148
# Dew_Point Temp_C          7148
# Rel Humidity_%            7148
# Wind Speed (km/h)         7148
# Wind Bearing (degrees)    7148
# Visibility_km             7148
# Loud Cover                7148
# Pressure (millibars)      7148
# Daily Forecast            7148
# dtype: int64

# %%
# to show all the data where foggy is mentioned 
# the result will show 7187 rows and previously it was 7148 rows 

data[data.Weather.str.contains ('Foggy')]
# Out:
#                       Formatted Date Weather Precip Type  Temperature_C  \
# 66     2006-04-11 18:00:00.000 +0200   Foggy        rain      10.911111
# 67     2006-04-11 19:00:00.000 +0200   Foggy        rain       8.800000
# 72     2006-04-12 00:00:00.000 +0200   Foggy        rain       8.200000
# 73     2006-04-12 01:00:00.000 +0200   Foggy        rain       8.177778
# 126    2006-04-14 06:00:00.000 +0200   Foggy        rain       5.211111
# ...                              ...     ...         ...            ...
# 95858  2016-09-14 05:00:00.000 +0200   Foggy        rain      13.144444
# 95859  2016-09-14 06:00:00.000 +0200   Foggy        rain      13.822222
# 95860  2016-09-14 07:00:00.000 +0200   Foggy        rain      13.872222
# 95907  2016-09-16 06:00:00.000 +0200   Foggy        rain      14.905556
# 96228  2016-09-28 15:00:00.000 +0200   Foggy        rain      22.800000
#
#        Dew_Point Temp_C  Rel Humidity_%  Wind Speed (km/h)  \
# ...

# %%
# how to check these rows 

data[data.Weather.str.contains ('Foggy')].head(50)
data[data.Weather.str.contains ('Foggy')].tail(100)

# %% [markdown]
# ## Q11. Find all instances when wind speed is above 24 and Visibility is 25

# %%
data [( data['Wind Speed (km/h)'] > 24 ) & ( data['Visibility_km'] >  2 )]
# Out:
#                       Formatted Date                   Weather Precip Type  \
# 37     2006-04-10 13:00:00.000 +0200             Mostly Cloudy        rain
# 38     2006-04-10 14:00:00.000 +0200             Mostly Cloudy        rain
# 39     2006-04-10 15:00:00.000 +0200             Mostly Cloudy        rain
# 40     2006-04-10 16:00:00.000 +0200             Mostly Cloudy        rain
# 67     2006-04-11 19:00:00.000 +0200                     Foggy        rain
# ...                              ...                       ...         ...
# 95940  2016-09-17 15:00:00.000 +0200  Breezy and Mostly Cloudy        rain
# 96030  2016-09-20 09:00:00.000 +0200             Mostly Cloudy        rain
# 96031  2016-09-20 10:00:00.000 +0200             Partly Cloudy        rain
# 96032  2016-09-20 11:00:00.000 +0200             Partly Cloudy        rain
# 96343  2016-09-05 10:00:00.000 +0200       Breezy and Overcast        rain
#
# ...

# %% [markdown]
# ## Q12. What is the Mean value of each column against Weather

# %%
data.groupby('Weather').mean()
# Out:
#                                      Temperature_C  Dew_Point Temp_C  \
# Weather
# Breezy                                    7.922016          3.387654
# Breezy and Dry                           21.111111         21.111111
# Breezy and Foggy                         -0.510317         -7.403492
# Breezy and Mostly Cloudy                 11.093411          8.680588
# Breezy and Overcast                       7.241614          3.492235
# Breezy and Partly Cloudy                 12.492761          9.989349
# Clear                                    11.925109         11.040338
# Dangerously Windy and Partly Cloudy       8.944444          3.483333
# Drizzle                                  10.847578         10.011681
# Dry                                      29.083660         28.273529
# Dry and Mostly Cloudy                    26.838492         25.929365
# Dry and Partly Cloudy                    26.605749         25.982235
# ...

# %% [markdown]
# ## Q13. What is the Mean value of Breezy and Dry in  Weather

# %%
data.groupby('Weather').get_group ('Breezy and Dry')
# Out:
#                       Formatted Date         Weather Precip Type  \
# 57947  2012-03-18 11:00:00.000 +0100  Breezy and Dry        rain
#
#        Temperature_C  Dew_Point Temp_C  Rel Humidity_%  Wind Speed (km/h)  \
# 57947      21.111111         21.111111            0.26              33.81
#
#        Wind Bearing (degrees)  Visibility_km  Loud Cover  \
# 57947                     240          9.982           0
#
#        Pressure (millibars)                            Daily Forecast
# 57947                1021.6  Partly cloudy starting in the afternoon.

# %% [markdown]
# ## Q14. What is the Maximum and Minimum value of each column against Weather

# %%
data.groupby('Weather').max()
# Out:
# C:\Users\Nidhin\AppData\Local\Temp/ipykernel_10508/1154048393.py:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.max is deprecated. In a future version, a TypeError will be raised. Before calling .max, select only columns which should be valid for the function.
#   data.groupby('Weather').max()
#                                                     Formatted Date  \
# Weather
# Breezy                               2016-08-05 10:00:00.000 +0200
# Breezy and Dry                       2012-03-18 11:00:00.000 +0100
# Breezy and Foggy                     2015-02-08 17:00:00.000 +0100
# Breezy and Mostly Cloudy             2016-09-17 15:00:00.000 +0200
# Breezy and Overcast                  2016-10-04 23:00:00.000 +0200
# Breezy and Partly Cloudy             2016-08-10 19:00:00.000 +0200
# Clear                                2016-11-02 23:00:00.000 +0100
# Dangerously Windy and Partly Cloudy  2007-01-29 13:00:00.000 +0100
# ...

# %%
data.groupby('Weather').min()
# Out:
# C:\Users\Nidhin\AppData\Local\Temp/ipykernel_10508/465539151.py:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.min is deprecated. In a future version, a TypeError will be raised. Before calling .min, select only columns which should be valid for the function.
#   data.groupby('Weather').min()
#                                                     Formatted Date  \
# Weather
# Breezy                               2006-09-17 12:00:00.000 +0200
# Breezy and Dry                       2012-03-18 11:00:00.000 +0100
# Breezy and Foggy                     2006-03-13 07:00:00.000 +0100
# Breezy and Mostly Cloudy             2006-01-22 17:00:00.000 +0100
# Breezy and Overcast                  2006-01-19 09:00:00.000 +0100
# Breezy and Partly Cloudy             2006-03-25 08:00:00.000 +0100
# Clear                                2006-01-08 01:00:00.000 +0100
# Dangerously Windy and Partly Cloudy  2007-01-29 13:00:00.000 +0100
# ...

# %% [markdown]
# ## Q15. Show all records where Weather is 'Mostly Cloudy'

# %%
data[data.Weather ==  'Mostly Cloudy']
# Out:
#                       Formatted Date        Weather Precip Type  \
# 2      2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain
# 4      2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain
# 17     2006-04-01 17:00:00.000 +0200  Mostly Cloudy        rain
# 18     2006-04-01 18:00:00.000 +0200  Mostly Cloudy        rain
# 19     2006-04-01 19:00:00.000 +0200  Mostly Cloudy        rain
# ...                              ...            ...         ...
# 96412  2016-09-08 07:00:00.000 +0200  Mostly Cloudy        rain
# 96413  2016-09-08 08:00:00.000 +0200  Mostly Cloudy        rain
# 96415  2016-09-08 10:00:00.000 +0200  Mostly Cloudy        rain
# 96416  2016-09-08 11:00:00.000 +0200  Mostly Cloudy        rain
# 96426  2016-09-08 21:00:00.000 +0200  Mostly Cloudy        rain
#
#        Temperature_C  Dew_Point Temp_C  Rel Humidity_%  Wind Speed (km/h)  \
# 2           9.377778          9.377778            0.89             3.9284
# ...

# %% [markdown]
# ## Q16. Show all records where Weather is 'Dry' or  Daily Forecast is 'Foggy overnight'

# %%
data[(data.Weather == 'Dry') | (data['Daily Forecast'] == 'Foggy overnight')]
# Out:
#                       Formatted Date Weather Precip Type  Temperature_C  \
# 12706  2007-07-20 10:00:00.000 +0200     Dry        rain      34.055556
# 12707  2007-07-20 11:00:00.000 +0200     Dry        rain      35.944444
# 12714  2007-07-20 18:00:00.000 +0200     Dry        rain      37.894444
# 12715  2007-07-20 19:00:00.000 +0200     Dry        rain      36.272222
# 12754  2007-07-22 10:00:00.000 +0200     Dry        rain      34.955556
# 12755  2007-07-22 11:00:00.000 +0200     Dry        rain      36.633333
# 12756  2007-07-22 12:00:00.000 +0200     Dry        rain      37.711111
# 12757  2007-07-22 13:00:00.000 +0200     Dry        rain      38.750000
# 12802  2007-07-24 10:00:00.000 +0200     Dry        rain      33.750000
# 12803  2007-07-24 11:00:00.000 +0200     Dry        rain      36.577778
# 12804  2007-07-24 12:00:00.000 +0200     Dry        rain      37.566667
# 12850  2007-07-26 10:00:00.000 +0200     Dry        rain      25.044444
# ...
