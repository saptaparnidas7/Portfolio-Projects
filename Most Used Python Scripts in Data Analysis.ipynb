# %%
import pandas as pd
import numpy as np
import seaborn as sns

import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import matplotlib
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8)

pd.options.mode.chained_assignment = None

# %% [markdown]
# ## pd.read_csv

# %%
# Now we need to read in the data

df = pd.read_csv(r'C:\Users\Nidhin\Desktop\Megha\Data Analysis\PROJECTS\Python\Movie Correlation in Python\movies.csv')

# %% [markdown]
# ## df.head()

# %%
df.head(2)
# Out:
#               name rating      genre  year                       released  \
# 0      The Shining      R      Drama  1980  June 13, 1980 (United States)
# 1  The Blue Lagoon      R  Adventure  1980   July 2, 1980 (United States)
#
#    score     votes         director                   writer            star  \
# 0    8.4  927000.0  Stanley Kubrick             Stephen King  Jack Nicholson
# 1    5.8   65000.0   Randal Kleiser  Henry De Vere Stacpoole  Brooke Shields
#
#           country      budget       gross            company  runtime
# 0  United Kingdom  19000000.0  46998772.0       Warner Bros.    146.0
# 1   United States   4500000.0  58853106.0  Columbia Pictures    104.0

# %% [markdown]
# ## df.tail()

# %%
df.tail(2)
# Out:
#               name rating   genre  year                         released  \
# 7666  It's Just Us    NaN   Drama  2020  October 1, 2020 (United States)
# 7667     Tee em el    NaN  Horror  2020  August 19, 2020 (United States)
#
#       score  votes       director         writer              star  \
# 7666    NaN    NaN  James Randall  James Randall     Christina Roz
# 7667    5.7    7.0   Pereko Mosia   Pereko Mosia  Siyabonga Mabaso
#
#             country   budget  gross      company  runtime
# 7666  United States  15000.0    NaN          NaN    120.0
# 7667   South Africa      NaN    NaN  PK 65 Films    102.0

# %% [markdown]
# ## df.describe()

# %%
df.describe()
# Out:
#               year        score         votes        budget         gross  \
# count  7668.000000  7665.000000  7.665000e+03  5.497000e+03  7.479000e+03
# mean   2000.405451     6.390411  8.810850e+04  3.558988e+07  7.850054e+07
# std      11.153508     0.968842  1.633238e+05  4.145730e+07  1.657251e+08
# min    1980.000000     1.900000  7.000000e+00  3.000000e+03  3.090000e+02
# 25%    1991.000000     5.800000  9.100000e+03  1.000000e+07  4.532056e+06
# 50%    2000.000000     6.500000  3.300000e+04  2.050000e+07  2.020576e+07
# 75%    2010.000000     7.100000  9.300000e+04  4.500000e+07  7.601669e+07
# max    2020.000000     9.300000  2.400000e+06  3.560000e+08  2.847246e+09
#
#            runtime
# count  7664.000000
# mean    107.261613
# std      18.581247
# min      55.000000
# 25%      95.000000
# 50%     104.000000
# 75%     116.000000
# max     366.000000

# %% [markdown]
# ## df.info()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7668 entries, 0 to 7667
# Data columns (total 15 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   name      7668 non-null   object
#  1   rating    7591 non-null   object
#  2   genre     7668 non-null   object
#  3   year      7668 non-null   int64
#  4   released  7666 non-null   object
#  5   score     7665 non-null   float64
#  6   votes     7665 non-null   float64
#  7   director  7668 non-null   object
#  8   writer    7665 non-null   object
#  9   star      7667 non-null   object
#  10  country   7665 non-null   object
#  11  budget    5497 non-null   float64
#  12  gross     7479 non-null   float64
#  13  company   7651 non-null   object
#  14  runtime   7664 non-null   float64
# dtypes: float64(5), int64(1), object(9)
# memory usage: 898.7+ KB

# %% [markdown]
# ## df.dtypes()

# %%
df.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget      float64
# gross       float64
# company      object
# runtime     float64
# dtype: object

# %% [markdown]
# ## df.plot()

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## df.iloc

# %%
# Select the first row


print(df.iloc[0])
# Out:
# name                          The Shining
# rating                                  R
# genre                               Drama
# year                                 1980
# released    June 13, 1980 (United States)
# score                                 8.4
# votes                            927000.0
# director                  Stanley Kubrick
# writer                       Stephen King
# star                       Jack Nicholson
# country                    United Kingdom
# budget                         19000000.0
# gross                          46998772.0
# company                      Warner Bros.
# runtime                             146.0
# Name: 0, dtype: object

# %%
## Select the first two rows

print(df.iloc[:2])
# Out:
#               name rating      genre  year                       released  \
# 0      The Shining      R      Drama  1980  June 13, 1980 (United States)
# 1  The Blue Lagoon      R  Adventure  1980   July 2, 1980 (United States)
#
#    score     votes         director                   writer            star  \
# 0    8.4  927000.0  Stanley Kubrick             Stephen King  Jack Nicholson
# 1    5.8   65000.0   Randal Kleiser  Henry De Vere Stacpoole  Brooke Shields
#
#           country      budget       gross            company  runtime
# 0  United Kingdom  19000000.0  46998772.0       Warner Bros.    146.0
# 1   United States   4500000.0  58853106.0  Columbia Pictures    104.0

# %%
# Select the first column

print(df.iloc[:, 0])
# Out:
# 0                                          The Shining
# 1                                      The Blue Lagoon
# 2       Star Wars: Episode V - The Empire Strikes Back
# 3                                            Airplane!
# 4                                           Caddyshack
#                              ...
# 7663                                      More to Life
# 7664                                       Dream Round
# 7665                                     Saving Mbango
# 7666                                      It's Just Us
# 7667                                         Tee em el
# Name: name, Length: 7668, dtype: object

# %%
# Select the first two columns

print(df.iloc[:, :2])
# Out:
#                                                 name rating
# 0                                        The Shining      R
# 1                                    The Blue Lagoon      R
# 2     Star Wars: Episode V - The Empire Strikes Back     PG
# 3                                          Airplane!     PG
# 4                                         Caddyshack      R
# ...                                              ...    ...
# 7663                                    More to Life    NaN
# 7664                                     Dream Round    NaN
# 7665                                   Saving Mbango    NaN
# 7666                                    It's Just Us    NaN
# 7667                                       Tee em el    NaN
#
# [7668 rows x 2 columns]

# %%
# Select the (1, 1) element

print(df.iloc[1, 1])
# Out:
# R

# %% [markdown]
# ## df.loc

# %%
# Select the column name 'name'

print(df.loc[:,'name'])
# Out:
# 0                                          The Shining
# 1                                      The Blue Lagoon
# 2       Star Wars: Episode V - The Empire Strikes Back
# 3                                            Airplane!
# 4                                           Caddyshack
#                              ...
# 7663                                      More to Life
# 7664                                       Dream Round
# 7665                                     Saving Mbango
# 7666                                      It's Just Us
# 7667                                         Tee em el
# Name: name, Length: 7668, dtype: object

# %%
# Select the columns named 'year' and 'released'

print(df.loc[:, ['year', 'released']])
# Out:
#       year                          released
# 0     1980     June 13, 1980 (United States)
# 1     1980      July 2, 1980 (United States)
# 2     1980     June 20, 1980 (United States)
# 3     1980      July 2, 1980 (United States)
# 4     1980     July 25, 1980 (United States)
# ...    ...                               ...
# 7663  2020  October 23, 2020 (United States)
# 7664  2020  February 7, 2020 (United States)
# 7665  2020         April 27, 2020 (Cameroon)
# 7666  2020   October 1, 2020 (United States)
# 7667  2020   August 19, 2020 (United States)
#
# [7668 rows x 2 columns]

# %% [markdown]
# ## df.assign()

# %%
#Pandas’ .assign() function is used to add new columns to a DataFrame, based on the computation of existing columns. 
#It allows you to add new columns to a DataFrame without modifying the original dataframe. The function returns a new DataFrame with the added columns

df_new = df.assign(year_plus_5=df['year'] + 5)

df_new.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %% [markdown]
# ## df.query()

# %%
# Select rows where year is greater than 1950 and budget is less than 10000

df_query1 = df.query('year > 1950 and budget < 10000')
df_query1.head()
# Out:
#                              name     rating   genre  year  \
# 471   A Polish Vampire in Burbank  Not Rated  Comedy  1983
# 2093                  El Mariachi          R  Action  1992
# 3318                    Following          R   Crime  1998
# 4507                       Primer      PG-13   Drama  2004
# 7658    Black Wall Street Burning          R   Drama  2020
#
#                                released  score     votes           director  \
# 471    October 31, 1983 (United States)    5.0     275.0         Mark Pirro
# 2093  February 26, 1993 (United States)    6.9   64000.0   Robert Rodriguez
# 3318  November 5, 1999 (United Kingdom)    7.5   89000.0  Christopher Nolan
# 4507               May 27, 2005 (Spain)    6.9  101000.0      Shane Carruth
# 7658   February 7, 2020 (United States)    6.6      35.0       Marcus Brown
#
#                  writer             star         country  budget      gross  \
# ...

# %%
# Select rows where genre is Action

df_query2 = df.query("genre == 'Action'")
df_query2.head()
# Out:
#                                               name rating   genre  year  \
# 2   Star Wars: Episode V - The Empire Strikes Back     PG  Action  1980
# 6                               The Blues Brothers      R  Action  1980
# 8                                      Superman II     PG  Action  1980
# 10                           Any Which Way You Can     PG  Action  1980
# 22                             The Final Countdown     PG  Action  1980
#
#                              released  score      votes        director  \
# 2       June 20, 1980 (United States)    8.7  1200000.0  Irvin Kershner
# 6       June 20, 1980 (United States)    7.9   188000.0     John Landis
# 8       June 19, 1981 (United States)    6.8   101000.0  Richard Lester
# 10  December 17, 1980 (United States)    6.1    18000.0  Buddy Van Horn
# 22     August 1, 1980 (United States)    6.7    22000.0      Don Taylor
#
#               writer            star        country      budget        gross  \
# ...

# %% [markdown]
# ## df.sort

# %%
#is meant to sort by the index labels (or a specific level of the index, or the column labels when axis=1)

df_sort = df.sort_index(axis = 1)
df_sort.head()
# Out:
#        budget             company         country         director      genre  \
# 0  19000000.0        Warner Bros.  United Kingdom  Stanley Kubrick      Drama
# 1   4500000.0   Columbia Pictures   United States   Randal Kleiser  Adventure
# 2  18000000.0           Lucasfilm   United States   Irvin Kershner     Action
# 3   3500000.0  Paramount Pictures   United States     Jim Abrahams     Comedy
# 4   6000000.0      Orion Pictures   United States     Harold Ramis     Comedy
#
#          gross                                            name rating  \
# 0   46998772.0                                     The Shining      R
# 1   58853106.0                                 The Blue Lagoon      R
# 2  538375067.0  Star Wars: Episode V - The Empire Strikes Back     PG
# 3   83453539.0                                       Airplane!     PG
# 4   39846344.0                                      Caddyshack      R
#
# ...

# %% [markdown]
# ## df.sort_values()

# %%
# is meant to sort by the values of columns . Sort by score in ascending order

df_sorted = df.sort_values(by='score')
df_sorted.head()
# Out:
#                               name rating   genre  year  \
# 5354       The Hottie & the Nottie  PG-13  Comedy  2008
# 4594  Superbabies: Baby Geniuses 2     PG  Comedy  2004
# 5306                Disaster Movie  PG-13  Comedy  2008
# 4412          From Justin to Kelly     PG  Comedy  2003
# 4342             House of the Dead      R  Action  2003
#
#                               released  score    votes         director  \
# 5354        February 21, 2008 (Russia)    1.9  36000.0       Tom Putnam
# 4594   August 27, 2004 (United States)    1.9  30000.0        Bob Clark
# 5306   August 29, 2008 (United States)    1.9  88000.0  Jason Friedberg
# 4412     June 20, 2003 (United States)    2.1  25000.0    Robert Iscove
# 4342  October 10, 2003 (United States)    2.1  36000.0         Uwe Boll
#
#                writer             star        country      budget       gross  \
# 5354     Heidi Ferrer     Paris Hilton  United States         NaN   1596232.0
# ...

# %%
#Sort by budget in descending order

df_sorted2 = df.sort_values(by = 'budget', ascending=False)

df_sorted2.head()
# Out:
#                                           name rating   genre  year  \
# 7445                         Avengers: Endgame  PG-13  Action  2019
# 7244                    Avengers: Infinity War  PG-13  Action  2018
# 7075   Star Wars: Episode VIII - The Last Jedi  PG-13  Action  2017
# 7066                            Justice League  PG-13  Action  2017
# 5060  Pirates of the Caribbean: at World's End  PG-13  Action  2007
#
#                                released  score     votes        director  \
# 7445     April 26, 2019 (United States)    8.4  903000.0   Anthony Russo
# 7244     April 27, 2018 (United States)    8.4  897000.0   Anthony Russo
# 7075  December 15, 2017 (United States)    7.0  581000.0    Rian Johnson
# 7066  November 17, 2017 (United States)    6.1  418000.0     Zack Snyder
# 5060       May 25, 2007 (United States)    7.1  608000.0  Gore Verbinski
#
#                   writer               star        country       budget  \
# ...

# %%
# Sort by multiple columns

df_sorted3 = df.sort_values(by=['budget', 'gross'])
df_sorted3.head()
# Out:
#                              name     rating   genre  year  \
# 471   A Polish Vampire in Burbank  Not Rated  Comedy  1983
# 7658    Black Wall Street Burning          R   Drama  2020
# 3318                    Following          R   Crime  1998
# 4507                       Primer      PG-13   Drama  2004
# 2093                  El Mariachi          R  Action  1992
#
#                                released  score     votes           director  \
# 471    October 31, 1983 (United States)    5.0     275.0         Mark Pirro
# 7658   February 7, 2020 (United States)    6.6      35.0       Marcus Brown
# 3318  November 5, 1999 (United Kingdom)    7.5   89000.0  Christopher Nolan
# 4507               May 27, 2005 (Spain)    6.9  101000.0      Shane Carruth
# 2093  February 26, 1993 (United States)    6.9   64000.0   Robert Rodriguez
#
#                  writer             star         country  budget      gross  \
# ...

# %% [markdown]
# ## df.sample()

# %%
# Sample 2 rows without replacement

df_sample = df.sample(n=2, replace=False, random_state=1)
df_sample
# Out:
#                    name rating      genre  year  \
# 2402  A Home of Our Own     PG  Biography  1993
# 1172          The Curse      R     Horror  1987
#
#                               released  score   votes     director  \
# 2402  November 5, 1993 (United States)    7.1  3000.0    Tony Bill
# 1172        September 14, 1988 (Spain)    5.1  2900.0  David Keith
#
#                      writer         star        country      budget  \
# 2402  Patrick Sheane Duncan  Kathy Bates  United States  12000000.0
# 1172          David Chaskin  Wil Wheaton          Italy         NaN
#
#           gross                          company  runtime
# 2402  1677807.0                        A&M Films    104.0
# 1172  1930001.0  Trans World Entertainment (TWE)     92.0

# %%
# Sample 2 rows without replacement with specific column to be chosen

df_sample = df.sample(n=2, replace=False, random_state=1, axis=1)
df_sample
# Out:
#       year         director
# 0     1980  Stanley Kubrick
# 1     1980   Randal Kleiser
# 2     1980   Irvin Kershner
# 3     1980     Jim Abrahams
# 4     1980     Harold Ramis
# ...    ...              ...
# 7663  2020    Joseph Ebanks
# 7664  2020     Dusty Dukatz
# 7665  2020     Nkanya Nkwai
# 7666  2020    James Randall
# 7667  2020     Pereko Mosia
#
# [7668 rows x 2 columns]

# %% [markdown]
# ## df.isnull()

# %%
df.isnull()
# Out:
#        name  rating  genre   year  released  score  votes  director  writer  \
# 0     False   False  False  False     False  False  False     False   False
# 1     False   False  False  False     False  False  False     False   False
# 2     False   False  False  False     False  False  False     False   False
# 3     False   False  False  False     False  False  False     False   False
# 4     False   False  False  False     False  False  False     False   False
# ...     ...     ...    ...    ...       ...    ...    ...       ...     ...
# 7663  False    True  False  False     False  False  False     False   False
# 7664  False    True  False  False     False  False  False     False   False
# 7665  False    True  False  False     False  False  False     False   False
# 7666  False    True  False  False     False   True   True     False   False
# 7667  False    True  False  False     False  False  False     False   False
#
#        star  country  budget  gross  company  runtime
# ...

# %% [markdown]
# ## df.fillna

# %%
# fill missing values in place
#inplace = False is temporary and inplace = True is permanent 

df.fillna(0, inplace=False)
# Out:
#                                                 name rating      genre  year  \
# 0                                        The Shining      R      Drama  1980
# 1                                    The Blue Lagoon      R  Adventure  1980
# 2     Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                          Airplane!     PG     Comedy  1980
# 4                                         Caddyshack      R     Comedy  1980
# ...                                              ...    ...        ...   ...
# 7663                                    More to Life      0      Drama  2020
# 7664                                     Dream Round      0     Comedy  2020
# 7665                                   Saving Mbango      0      Drama  2020
# 7666                                    It's Just Us      0      Drama  2020
# 7667                                       Tee em el      0     Horror  2020
#
# ...

# %% [markdown]
# ## df.dropna()

# %%
#You can remove all rows containing at least one missing value by calling

df = df.dropna()

# %%
#If you want to remove only the columns that contain at least one missing value you can use 

df = df.dropna(axis=1)

# %% [markdown]
# ## df.drop()

# %%
#You can remove a specific row by calling df.drop() and passing the index label of the row you want to remove, and the axis parameter set to 0 (default is 0)
# This would remove the first row of the DataFrame.
     
df_drop = df.drop(0)

# %%
#You can also drop multiple rows by passing a list of index labels:
#This would remove the first and second rows of the DataFrame

df_drop = df.drop([0,1])

# %%
#Similarly, you can drop columns by passing the labels of the columns you want to remove and setting the axis parameter to 1:


df_drop = df.drop(['votes', 'writer'], axis=1)

# %% [markdown]
# ## pd.pivot_table()

# %%
df.head(0)
# Out:
# Empty DataFrame
# Columns: [name, rating, genre, year, released, score, votes, director, writer, star, country, budget, gross, company, runtime]
# Index: []

# %%
#index = column1 values = column 2

pivot_table = pd.pivot_table(df, index='genre', values='budget', aggfunc='sum')

pivot_table.head()
# Out:
#                  budget
# genre
# Action     8.273301e+10
# Adventure  1.502856e+10
# Animation  2.114157e+10
# Biography  7.912359e+09
# Comedy     3.411235e+10

# %%
#You can also include more columns in the pivot table by specifying multiple index and values parameters and also include multiple aggfunc functions.

pivot_table = pd.pivot_table(df, index=['genre','rating'], values= 'budget' , aggfunc=['sum','count'])
pivot_table.head(20)
# Out:
#                               sum  count
#                            budget budget
# genre     rating
# Action    Not Rated  1.543261e+08      5
#           PG         6.365240e+09    146
#           PG-13      5.201483e+10    586
#           R          2.415062e+10    677
#           TV-MA      4.800000e+07      1
# Adventure Approved   6.500000e+06      1
#           G          4.320000e+08     13
#           PG         8.339160e+09    166
#           PG-13      4.361500e+09     76
#           R          1.889400e+09     71
# Animation G          5.044570e+09     82
#           Not Rated  8.000000e+06      1
#           PG         1.541140e+10    175
#           PG-13      6.159000e+08     13
#           R          6.170000e+07      6
# Biography G          1.000000e+07      1
#           Not Rated  3.700000e+07      2
#           PG         1.020600e+09     46
#           PG-13      3.097698e+09    109
#           R          3.746950e+09    152

# %% [markdown]
# ## df.groupby()

# %%
#df.groupby() returns a GroupBy object, which you can then use to perform various operations on the groups, such as calculating the sum, mean, or count of the values in each group.


grouped = df.groupby('genre')

# Print the mean of each group
print(grouped.mean())
# Out:
#                   year     score          votes        budget         gross  \
# genre
# Action     2002.605654  6.247350  163347.154770  5.846856e+07  1.680232e+08
# Adventure  2000.464832  6.268196  123237.440367  4.595890e+07  1.332682e+08
# Animation  2006.404332  6.690614  147508.743682  7.632336e+07  2.811044e+08
# Biography  2005.408360  7.088103  116086.041801  2.544167e+07  6.139527e+07
# Comedy     2000.108289  6.190709   71959.481283  2.280237e+07  5.916766e+07
# Crime      1999.927318  6.689223  113727.568922  2.260290e+07  5.016958e+07
# Drama      2001.731170  6.721437  107510.027810  2.324188e+07  6.036914e+07
# Family     1999.000000  6.675000  173225.000000  5.112500e+07  5.185831e+08
# Fantasy    1996.512195  6.048780   61951.219512  1.722439e+07  3.987870e+07
# Horror     2001.139442  5.827490   82038.645418  1.343453e+07  5.681695e+07
# Mystery    1999.470588  6.670588  266647.058824  3.187647e+07  1.178877e+08
# ...

# %%
grouped1 = df.groupby([ 'country','year'])

# Print the sum of each group
print(grouped1.sum())
# Out:
#                     score     votes       budget         gross  runtime
# country       year
# Argentina     2000    7.9   51000.0    1500000.0  1.241389e+07    114.0
#               2009    8.2  198000.0    2000000.0  3.507965e+07    129.0
#               2014    8.1  184000.0    3300000.0  3.064270e+07    122.0
# Aruba         1998    4.9   14000.0   30000000.0  1.031992e+07     91.0
# Australia     1981    7.6  170000.0    3000000.0  2.366837e+07     96.0
# ...                   ...       ...          ...           ...      ...
# United States 2020   32.2  872000.0  639500000.0  1.557224e+09    583.0
# West Germany  1980    6.5   20000.0   11000000.0  1.981452e+07    102.0
#               1981    6.6   22000.0   12000000.0  1.237662e+07    122.0
#               1984    7.4  135000.0   27000000.0  2.025141e+07    102.0
# Yugoslavia    1985    5.0    6900.0    3000000.0  7.196872e+06     93.0
#
# [417 rows x 5 columns]

# %% [markdown]
# ## df.rename()

# %%
# Rename column 'gross' to 'Box Office'

df_rename = df.rename(columns={'gross': 'Box Office'})
df_rename.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %% [markdown]
# ## df.transpose()

# %%
# Transpose the DataFrame
df_transposed = df.transpose()
# Out:
#                                    0                             1     \
# name                        The Shining               The Blue Lagoon
# rating                                R                             R
# genre                             Drama                     Adventure
# year                               1980                          1980
# released  June 13, 1980 (United States)  July 2, 1980 (United States)
#
#                                                     2     \
# name      Star Wars: Episode V - The Empire Strikes Back
# rating                                                PG
# genre                                             Action
# year                                                1980
# released                   June 20, 1980 (United States)
#
#                                   3                              4     \
# name                         Airplane!                     Caddyshack
# ...

# %%
# Print the transposed DataFrame
df_transposed.head()
# Out:
#                                    0                             1     \
# name                        The Shining               The Blue Lagoon
# rating                                R                             R
# genre                             Drama                     Adventure
# year                               1980                          1980
# released  June 13, 1980 (United States)  July 2, 1980 (United States)
#
#                                                     2     \
# name      Star Wars: Episode V - The Empire Strikes Back
# rating                                                PG
# genre                                             Action
# year                                                1980
# released                   June 20, 1980 (United States)
#
#                                   3                              4     \
# name                         Airplane!                     Caddyshack
# ...

# %% [markdown]
# ## df.merge()

# %%
# Create the first DataFrame
df1 = pd.DataFrame({'key': ['A', 'B', 'C', 'D'],
                   'value': [1, 2, 3, 4]})

# Create the second DataFrame
df2 = pd.DataFrame({'key': ['B', 'D', 'E', 'F'],
                   'value': [5, 6, 7, 8]})

# Merge the two DataFrames on the 'key' column
merged_df = df1.merge(df2, on='key')

# Print the merged DataFrame
print(merged_df)
# Out:
#   key  value_x  value_y
# 0   B        2        5
# 1   D        4        6

# %% [markdown]
# ## df.to_csv()

# %%
#You can export the DataFrame to a CSV file by calling df.to_csv() and passing the file name as a string

df.to_csv('data.csv')

df.to_csv('path/to/data.csv')

df.to_csv('path/to/data.csv', columns=['score','released'])
